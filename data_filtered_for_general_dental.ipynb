# %%
import pandas as pd

# %%
df = pd.read_csv('data/adult22.csv')

# %%
survey = df[['SRVY_YR','INTV_MON','HHX','URBRRL','REGION','SEX_A','AGEP_A','EDUCP_A',
    'PCNTLT18TC','PCNT18UPTC','PHSTAT_A','LSATIS4_A','RATCAT_A',
    'DENPREV_A','DENDL12M_A','DENNG12M_A']]

# %%
survey.to_csv('data/survey22.csv',index=False)

# %%
pd.read_csv('data/survey22.csv')
# Out:
#        SRVY_YR  INTV_MON      HHX  URBRRL  REGION  SEX_A  AGEP_A  EDUCP_A  \
# 0         2022         1  H059086       2       3      1      85        4
# 1         2022         1  H054049       4       3      1      64        8
# 2         2022         1  H055201       4       3      2      37        8
# 3         2022         1  H044893       4       3      2      72        5
# 4         2022         1  H043149       1       3      2      84        6
# ...        ...       ...      ...     ...     ...    ...     ...      ...
# 27646     2022        12  H015345       4       4      1      64        4
# 27647     2022        12  H061055       4       4      2      67        8
# 27648     2022        12  H031575       4       4      2      69        7
# 27649     2022        12  H015667       4       4      1      30        7
# 27650     2022        12  H067367       4       4      1      51        9
#
#        PCNTLT18TC  PCNT18UPTC  PHSTAT_A  LSATIS4_A  RATCAT_A  DENPREV_A  \
# ...
